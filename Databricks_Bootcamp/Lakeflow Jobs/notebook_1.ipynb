# %%
df =  spark.read.format("csv")\
    .option("header" , True)\
    .option("inferSchema" , True)\
    .load("/Volumes/databricksansh/bronze/bronze_volume/stores/")

# %%
df.write.format("delta")\
    .mode("overwrite")\
    .save("/Volumes/databricksansh/bronze/jobvolume/raw/stores")
