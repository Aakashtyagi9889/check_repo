-- %%
create table databricksansh.bronze.lookup_table
(
    parent_folder_name string,
    folder_name string
)
insert into databricksansh.bronze.lookup_table
values
("raw" , "customers"),
("raw" , "products"),
("raw" , "stores"),
("raw" , "sales")

select * from databricksansh.bronze.lookup_table
