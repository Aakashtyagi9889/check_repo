# %% [markdown]
# # **Use Text Files**

# %%
# I want to use file.txt , i want to read what has it contain

with open("/Workspace/Databricks_Bootcamp/silver_layer/file.txt" , "r") as file:
    content =  file.read()
    # print(file.read())
print(content)
# Out:
# Hello Aakash Tyagi

# %%
#  If you dont have the file , and you want to create it 

with open("/Workspace/Databricks_Bootcamp/silver_layer/Create.txt" , "w") as file2:
    file2.write("hello world")

# %% [markdown]
# ## Python file

# %%
with open("/Workspace/Databricks_Bootcamp/silver_layer/Pythonfile.py" , "w") as file3:
    file3.write("my_screte = '1234'")

# %%
import Pythonfile

# %%
Pythonfile.my_screte
# Out:
# '1234'

# %% [markdown]
# ### **JSON FILES**

# %%
import pandas as pd
with open("/Workspace/Databricks_Bootcamp/silver_layer/mapping.json" ,"r") as j:
    df = pd.read_json(j)
df
# Out:
#    id name
# 0   1   aa
# 1   2   bb
# 2   3   cc
# 3   4   dd
# 4   5   ee

# %%
df = pd.read_json("/Workspace/Databricks_Bootcamp/silver_layer/mapping.json")
df
# Out:
#    id name
# 0   1   aa
# 1   2   bb
# 2   3   cc
# 3   4   dd
# 4   5   ee

# %% [markdown]
# ## Convert it into  pyspark dataframe

# %%
df_pyspark = spark.createDataFrame(df)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th></tr></thead><tbody><tr><td>1</td><td>aa</td></tr><tr><td>2</td><td>bb</td></tr><tr><td>3</td><td>cc</td></tr><tr><td>4</td><td>dd</td></tr><tr><td>5</td><td>ee</td></tr></tbody></table></div>
