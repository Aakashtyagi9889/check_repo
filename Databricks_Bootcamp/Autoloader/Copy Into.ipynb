# %%
# %sql
select * from parquet.`/Volumes/databricksansh/bronze/autovol/COPYINTO/part-00000-tid-1800520145580676501-2fb00642-a896-4599-9957-2c7260f04aa7-132-1.c000.snappy.parquet`

# %%
# %sql
drop table if exists databricksansh.bronze.copyintotbl

# %%
# %sql
create table databricksansh.bronze.copyintotbl
(
    order_id int,
    customer_id int,
    order_date date,
    order_amount double ,
    order_status string
)

# %%
# %sql
copy into databricksansh.bronze.copyintotbl
from "/Volumes/databricksansh/bronze/autovol/COPYINTO/"
FILEFORMAT = PARQUET
format_options('mergeSchema' = "True")
copy_options ("mergeSchema"= "True")

# %%
# %sql
select * from databricksansh.bronze.copyintotbl
