-- %%
--  Adding parameter 
-- select * from products_enr
-- where category = :para_catagoery;

-- Adding parameter for column
-- select identifier(:para_col1) , identifier(:para_col2) from products_enr;


-- snippets 
-- select * from products_enr
-- where category  = "Toys"  it uses snippits
